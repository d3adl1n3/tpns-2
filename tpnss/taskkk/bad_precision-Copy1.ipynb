# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# Загрузка данных
df_train = pd.read_csv('mnist_train.csv')
df_test = pd.read_csv('mnist_test.csv')

# Подготовка данных
x_train = df_train.iloc[:, 1:].values.reshape(-1, 28, 28, 1).astype('float32') / 255.0
y_train = df_train.iloc[:, 0].values
x_test = df_test.iloc[:, 1:].values.reshape(-1, 28, 28, 1).astype('float32') / 255.0
y_test = df_test.iloc[:, 0].values

# One-hot encoding меток
y_train = np.eye(10)[y_train]
y_test = np.eye(10)[y_test]

# Функции для слоев сети
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return sigmoid(x) * (1 - sigmoid(x))

def convolve2d(X, K, stride=1):
    X_h, X_w, X_c = X.shape
    K_h, K_w, K_c, K_n = K.shape
    assert X_c == K_c, "Количество каналов в X и K должно совпадать"
    Y_h = (X_h - K_h) // stride + 1
    Y_w = (X_w - K_w) // stride + 1
    Y = np.zeros((Y_h, Y_w, K_n))
    for k in range(K_n):
        for i in range(0, Y_h):
            for j in range(0, Y_w):
                Y[i, j, k] = np.sum(X[i*stride:i*stride+K_h, j*stride:j*stride+K_w, :] * K[:, :, :, k])
    return Y

def pool2d(X, size=2, stride=2, mode='max'):
    X_h, X_w, X_c = X.shape
    Y_h = (X_h - size) // stride + 1
    Y_w = (X_w - size) // stride + 1
    Y = np.zeros((Y_h, Y_w, X_c))
    for c in range(X_c):
        for i in range(0, Y_h):
            for j in range(0, Y_w):
                if mode == 'max':
                    Y[i, j, c] = np.max(X[i*stride:i*stride+size, j*stride:j*stride+size, c])
                elif mode == 'average':
                    Y[i, j, c] = np.mean(X[i*stride:i*stride+size, j*stride:j*stride+size, c])
    return Y

def flatten(X):
    return X.flatten()

def dense(X, W, b):
    return np.dot(X, W) + b

def cross_entropy_loss(y_true, y_pred):
    return -np.sum(y_true * np.log(y_pred + 1e-8))

# Инициализация параметров
np.random.seed(0)

# Параметры первого сверточного слоя
conv1_filters = 6
conv1_kernel = np.random.randn(5, 5, 1, conv1_filters) * 0.1
conv1_bias = np.zeros(conv1_filters)

# Параметры второго сверточного слоя
conv2_filters = 16
conv2_kernel = np.random.randn(5, 5, conv1_filters, conv2_filters) * 0.1
conv2_bias = np.zeros(conv2_filters)

# Параметры полносвязных слоев
fc1_units = 120
fc1_weights = np.random.randn(16*4*4, fc1_units) * 0.1
fc1_bias = np.zeros(fc1_units)

fc2_units = 84
fc2_weights = np.random.randn(fc1_units, fc2_units) * 0.1
fc2_bias = np.zeros(fc2_units)

fc3_units = 10
fc3_weights = np.random.randn(fc2_units, fc3_units) * 0.1
fc3_bias = np.zeros(fc3_units)

# Прямое распространение
def forward(X):
    cache = {}
    
    # Первый сверточный слой
    conv1 = convolve2d(X, conv1_kernel) + conv1_bias
    conv1 = np.maximum(conv1, 0)  # ReLU активация
    pool1 = pool2d(conv1, mode='average')
    
    # Второй сверточный слой
    conv2 = convolve2d(pool1, conv2_kernel) + conv2_bias
    conv2 = np.maximum(conv2, 0)  # ReLU активация
    pool2 = pool2d(conv2, mode='average')
    
    # Флаттен
    flat = flatten(pool2)
    
    # Полносвязные слои
    fc1 = np.maximum(dense(flat, fc1_weights, fc1_bias), 0)  # ReLU активация
    fc2 = np.maximum(dense(fc1, fc2_weights, fc2_bias), 0)  # ReLU активация
    fc3 = sigmoid(dense(fc2, fc3_weights, fc3_bias))  # Сигмоид активация для предсказаний
    
    cache['conv1'] = conv1
    cache['pool1'] = pool1
    cache['conv2'] = conv2
    cache['pool2'] = pool2
    cache['flat'] = flat
    cache['fc1'] = fc1
    cache['fc2'] = fc2
    cache['fc3'] = fc3
    
    return fc3, cache

# Обратное распространение и обновление параметров
def backward(X, y_true, y_pred, cache, learning_rate=0.001):
    global fc3_weights, fc3_bias, fc2_weights, fc2_bias, fc1_weights, fc1_bias
    # Градиенты
    d_loss = y_pred - y_true
    
    # Полносвязные слои
    d_fc3_weights = np.dot(cache['fc2'].reshape(-1, 1), d_loss.reshape(1, -1))
    d_fc3_bias = np.sum(d_loss, axis=0)
    
    d_fc2 = np.dot(d_loss, fc3_weights.T) * sigmoid_derivative(cache['fc2'])
    d_fc2_weights = np.dot(cache['fc1'].reshape(-1, 1), d_fc2.reshape(1, -1))
    d_fc2_bias = np.sum(d_fc2, axis=0)
    
    d_fc1 = np.dot(d_fc2, fc2_weights.T) * sigmoid_derivative(cache['fc1'])
    d_fc1_weights = np.dot(cache['flat'].reshape(-1, 1), d_fc1.reshape(1, -1))
    d_fc1_bias = np.sum(d_fc1, axis=0)
    
    # Обновление параметров полносвязных слоев
    fc3_weights -= learning_rate * d_fc3_weights
    fc3_bias -= learning_rate * d_fc3_bias
    
    fc2_weights -= learning_rate * d_fc2_weights
    fc2_bias -= learning_rate * d_fc2_bias
    
    fc1_weights -= learning_rate * d_fc1_weights
    fc1_bias -= learning_rate * d_fc1_bias
    
    # Градиенты для сверточных слоев
    # Пропускаем подробности из-за сложности
    # Вы можете использовать аналогичные подходы для сверточных слоев
    
# Обучение модели
def train(X_train, y_train, epochs=10, batch_size=32, learning_rate=0.001):
    print("training started")
    for epoch in range(epochs):
        permutation = np.random.permutation(X_train.shape[0])
        X_train = X_train[permutation]
        y_train = y_train[permutation]

        for i in range(0, X_train.shape[0], batch_size):
            if (i % 100 == 0):
                print(i, "out of: 60 000") 
            X_batch = X_train[i:i+batch_size]
            y_batch = y_train[i:i+batch_size]
            
            for j in range(X_batch.shape[0]):
                y_pred, cache = forward(X_batch[j])  # используем одно изображение за раз
                loss = cross_entropy_loss(y_batch[j], y_pred)
                backward(X_batch[j], y_batch[j], y_pred, cache, learning_rate)
        
        print(f'Epoch {epoch+1}, Loss: {loss}')

# Обучение модели
train(x_train, y_train)

# Оценка модели
correct_predictions = 0
for i in range(x_test.shape[0]):
    y_pred, _ = forward(x_test[i])
    if np.argmax(y_pred) == np.argmax(y_test[i]):
        correct_predictions += 1

test_accuracy = correct_predictions / x_test.shape[0]
print(f'Test accuracy: {test_accuracy:.4f}')
# Out:
# training started
# 0 out of: 60 000
# 800 out of: 60 000
# 1600 out of: 60 000
# 2400 out of: 60 000
# 3200 out of: 60 000
# 4000 out of: 60 000
# 4800 out of: 60 000
# 5600 out of: 60 000
# 6400 out of: 60 000
# 7200 out of: 60 000
# 8000 out of: 60 000
# 8800 out of: 60 000
# 9600 out of: 60 000
# 10400 out of: 60 000
# 11200 out of: 60 000
# 12000 out of: 60 000
# 12800 out of: 60 000
# 13600 out of: 60 000
# 14400 out of: 60 000
# 15200 out of: 60 000
# 16000 out of: 60 000
# 16800 out of: 60 000
# 17600 out of: 60 000
# 18400 out of: 60 000
# 19200 out of: 60 000
# 20000 out of: 60 000
# 20800 out of: 60 000
# 21600 out of: 60 000
# 22400 out of: 60 000
# 23200 out of: 60 000
# 24000 out of: 60 000
# 24800 out of: 60 000
# 25600 out of: 60 000
# 26400 out of: 60 000
# 27200 out of: 60 000
# 28000 out of: 60 000
# 28800 out of: 60 000
# 29600 out of: 60 000
# 30400 out of: 60 000
# 31200 out of: 60 000
# 32000 out of: 60 000
# 32800 out of: 60 000
# 33600 out of: 60 000
# 34400 out of: 60 000
# 35200 out of: 60 000
# 36000 out of: 60 000
# 36800 out of: 60 000
# 37600 out of: 60 000
# 38400 out of: 60 000
# 39200 out of: 60 000
# 40000 out of: 60 000
# 40800 out of: 60 000
# 41600 out of: 60 000
# 42400 out of: 60 000
# 43200 out of: 60 000
# 44000 out of: 60 000
# 44800 out of: 60 000
# 45600 out of: 60 000
# 46400 out of: 60 000
# 47200 out of: 60 000
# 48000 out of: 60 000
# 48800 out of: 60 000
# 49600 out of: 60 000
# 50400 out of: 60 000
# 51200 out of: 60 000
# 52000 out of: 60 000
# 52800 out of: 60 000
# 53600 out of: 60 000
# 54400 out of: 60 000
# 55200 out of: 60 000
# 56000 out of: 60 000
# 56800 out of: 60 000
# 57600 out of: 60 000
# 58400 out of: 60 000
# 59200 out of: 60 000
# Epoch 1, Loss: 1.301907906714779
# 0 out of: 60 000
# 800 out of: 60 000
# 1600 out of: 60 000
# 2400 out of: 60 000
# 3200 out of: 60 000
# 4000 out of: 60 000
# 4800 out of: 60 000
# 5600 out of: 60 000
# 6400 out of: 60 000
# 7200 out of: 60 000
# 8000 out of: 60 000
# 8800 out of: 60 000
# 9600 out of: 60 000
# 10400 out of: 60 000
# 11200 out of: 60 000
# 12000 out of: 60 000
# 12800 out of: 60 000
# 13600 out of: 60 000
# 14400 out of: 60 000
# 15200 out of: 60 000
# 16000 out of: 60 000
# 16800 out of: 60 000
# 17600 out of: 60 000
# 18400 out of: 60 000
# 19200 out of: 60 000
# 20000 out of: 60 000
# 20800 out of: 60 000
# 21600 out of: 60 000
# 22400 out of: 60 000
# 23200 out of: 60 000
# 24000 out of: 60 000
# 24800 out of: 60 000
# 25600 out of: 60 000
# 26400 out of: 60 000
# 27200 out of: 60 000
# 28000 out of: 60 000
# 28800 out of: 60 000
# 29600 out of: 60 000
# 30400 out of: 60 000
# 31200 out of: 60 000
# 32000 out of: 60 000
# 32800 out of: 60 000
# 33600 out of: 60 000
# 34400 out of: 60 000
# 35200 out of: 60 000
# 36000 out of: 60 000
# 36800 out of: 60 000
# 37600 out of: 60 000
# 38400 out of: 60 000
# 39200 out of: 60 000
# 40000 out of: 60 000
# 40800 out of: 60 000
# 41600 out of: 60 000
# 42400 out of: 60 000
# 43200 out of: 60 000
# 44000 out of: 60 000
# 44800 out of: 60 000
# 45600 out of: 60 000
# 46400 out of: 60 000
# 47200 out of: 60 000
# 48000 out of: 60 000
# 48800 out of: 60 000
# 49600 out of: 60 000
# 50400 out of: 60 000
# 51200 out of: 60 000
# 52000 out of: 60 000
# 52800 out of: 60 000
# 53600 out of: 60 000
# 54400 out of: 60 000
# 55200 out of: 60 000
# 56000 out of: 60 000
# 56800 out of: 60 000
# 57600 out of: 60 000
# 58400 out of: 60 000
# 59200 out of: 60 000
# Epoch 2, Loss: 0.39781567128504647
# 0 out of: 60 000
# 800 out of: 60 000
# 1600 out of: 60 000
# 2400 out of: 60 000
# 3200 out of: 60 000
# 4000 out of: 60 000
# 4800 out of: 60 000
# 5600 out of: 60 000
# 6400 out of: 60 000
# 7200 out of: 60 000
# 8000 out of: 60 000
# 8800 out of: 60 000
# 9600 out of: 60 000
# 10400 out of: 60 000
# 11200 out of: 60 000
# 12000 out of: 60 000
# 12800 out of: 60 000
# 13600 out of: 60 000
# 14400 out of: 60 000
# 15200 out of: 60 000
# 16000 out of: 60 000
# 16800 out of: 60 000
# 17600 out of: 60 000
# 18400 out of: 60 000
# 19200 out of: 60 000
# 20000 out of: 60 000
# 20800 out of: 60 000
# 21600 out of: 60 000
# 22400 out of: 60 000
# 23200 out of: 60 000
# 24000 out of: 60 000
# 24800 out of: 60 000
# 25600 out of: 60 000
# 26400 out of: 60 000
# 27200 out of: 60 000
# 28000 out of: 60 000
# 28800 out of: 60 000
# 29600 out of: 60 000
# 30400 out of: 60 000
# 31200 out of: 60 000
# 32000 out of: 60 000
# 32800 out of: 60 000
# 33600 out of: 60 000
# 34400 out of: 60 000
# 35200 out of: 60 000
# 36000 out of: 60 000
# 36800 out of: 60 000
# 37600 out of: 60 000
# 38400 out of: 60 000
# 39200 out of: 60 000
# 40000 out of: 60 000
# 40800 out of: 60 000
# 41600 out of: 60 000
# 42400 out of: 60 000
# 43200 out of: 60 000
# 44000 out of: 60 000
# 44800 out of: 60 000
# 45600 out of: 60 000
# 46400 out of: 60 000
# 47200 out of: 60 000
# 48000 out of: 60 000
# 48800 out of: 60 000
# 49600 out of: 60 000
# 50400 out of: 60 000
# 51200 out of: 60 000
# 52000 out of: 60 000
# 52800 out of: 60 000
# 53600 out of: 60 000
# 54400 out of: 60 000
# 55200 out of: 60 000
# 56000 out of: 60 000
# 56800 out of: 60 000
# 57600 out of: 60 000
# 58400 out of: 60 000
# 59200 out of: 60 000
# Epoch 3, Loss: 1.14190197063655
# 0 out of: 60 000
# 800 out of: 60 000
# 1600 out of: 60 000
# 2400 out of: 60 000
# 3200 out of: 60 000
# 4000 out of: 60 000
# 4800 out of: 60 000
# 5600 out of: 60 000
# 6400 out of: 60 000
# 7200 out of: 60 000
# 8000 out of: 60 000
# 8800 out of: 60 000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 176
#     173         print(f'Epoch {epoch+1}, Loss: {loss}')
#     175 # Обучение модели
# --> 176 train(x_train, y_train)
#     178 # Оценка модели
#     179 correct_predictions = 0
#
# Cell In[2], line 169, in train(X_train, y_train, epochs, batch_size, learning_rate)
#     166 y_batch = y_train[i:i+batch_size]
#     168 for j in range(X_batch.shape[0]):
# --> 169     y_pred, cache = forward(X_batch[j])  # используем одно изображение за раз
#     170     loss = cross_entropy_loss(y_batch[j], y_pred)
#     171     backward(X_batch[j], y_batch[j], y_pred, cache, learning_rate)
#
# Cell In[2], line 94, in forward(X)
#      91 cache = {}
#      93 # Первый сверточный слой
# ---> 94 conv1 = convolve2d(X, conv1_kernel) + conv1_bias
#      95 conv1 = np.maximum(conv1, 0)  # ReLU активация
#      96 pool1 = pool2d(conv1, mode='average')
#
# Cell In[2], line 37, in convolve2d(X, K, stride)
#      35     for i in range(0, Y_h):
#      36         for j in range(0, Y_w):
# ---> 37             Y[i, j, k] = np.sum(X[i*stride:i*stride+K_h, j*stride:j*stride+K_w, :] * K[:, :, :, k])
#      38 return Y
#
# File <__array_function__ internals>:200, in sum(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2188, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2183 def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2184                     initial=None, where=None):
#    2185     return (a, out)
# -> 2188 @array_function_dispatch(_sum_dispatcher)
#    2189 def sum(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2190         initial=np._NoValue, where=np._NoValue):
#    2191     """
#    2192     Sum of array elements over a given axis.
#    2193
#    (...)
#    2309     15
#    2310     """
#    2311     if isinstance(a, _gentype):
#    2312         # 2018-02-25, 1.15.0
#
# KeyboardInterrupt:
